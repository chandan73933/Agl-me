# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inLine
from apyori import apriori
from sklearn.cluster import KMeans
from sklearn.preprocessing import MinMaxScaler
import scipy.stats as st

# %%
df=pd.read_csv("Desktop/customerdata.csv")
# Out:
# C:\Users\AGL\AppData\Local\Temp\ipykernel_20800\2389087265.py:1: DtypeWarning: Columns (11,12,21,22,26,42) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv("Desktop/customerdata.csv")

# %%
#st.pearsonr(df['model'],df['model'])

# %%
#np.corrcoef(df.head(20)['model'],df.head(20)['model'])

# %%
#finding corelation between the model feature
sns.scatterplot(df.head(50)['model'],df.head(50)['model'])
# Out:
# C:\Users\AGL\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='model', ylabel='model'>

# %%
#generating corelation between each feature
df.corr()
# Out:
#                       timestamp  tfirstname  tmiddlename  tlastname  \
# timestamp                   NaN         NaN          NaN        NaN
# tfirstname                  NaN         NaN          NaN        NaN
# tmiddlename                 NaN         NaN          NaN        NaN
# tlastname                   NaN         NaN          NaN        NaN
# contact_name                NaN         NaN          NaN        NaN
# address1                    NaN         NaN          NaN        NaN
# address2                    NaN         NaN          NaN        NaN
# street                      NaN         NaN          NaN        NaN
# ddateofbirth                NaN         NaN          NaN        NaN
# material                    NaN         NaN          NaN        NaN
# ean_upc                     NaN         NaN          NaN        NaN
# division                    NaN         NaN          NaN        NaN
# recieve_lead_time           NaN         NaN          NaN        NaN
# ...

# %%
#ploting the corelation between each feature on the whole dataset upto top 50 row 
sns.pairplot(df.head(50))

# %%
#finding corelation of each feature with other using heatmap
sns.heatmap(df.corr())
# Out:
# <AxesSubplot:>
